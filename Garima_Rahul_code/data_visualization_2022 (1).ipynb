# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %%
df = pd.read_csv('C:/Users/Antino/Desktop/al_ml_tranning_module_one/Invoice_2022/new_file.csv',
                 dtype={'column_name1': str, 'column_name2': float},
                 low_memory=False)

# %%
df.head()
# Out:
#            Invoice ID Invoice Status         Customer ID  SubTotal    Total
# 0  209792000042057563         Closed  209792000000741828   57222.5  54361.4  \
# 1  209792000042057563         Closed  209792000000741828   57222.5  54361.4
# 2  209792000042057563         Closed  209792000000741828   57222.5  54361.4
# 3  209792000042057563         Closed  209792000000741828   57222.5  54361.4
# 4  209792000042057563         Closed  209792000000741828   57222.5  54361.4
#
#    Balance  Adjustment Last Payment Date                   Item Name
# 0      0.0     -2861.1        2022-01-02                  Basil (Kg)  \
# 1      0.0     -2861.1        2022-01-02        Beans (Horicot) (Kg)
# 2      0.0     -2861.1        2022-01-02  Brinjal (Bottle Black) (Kg
# 3      0.0     -2861.1        2022-01-02  Bottle Gourd (Medium) (Kg)
# 4      0.0     -2861.1        2022-01-02         Broccoli (Big) (Kg)
#
#   Item Desc  ...  Discount  Discount Amount  Item Total  Item Price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 993869 entries, 0 to 993868
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Invoice ID         993869 non-null  int64
#  1   Invoice Status     993869 non-null  object
#  2   Customer ID        993869 non-null  int64
#  3   SubTotal           993869 non-null  float64
#  4   Total              993869 non-null  float64
#  5   Balance            993869 non-null  float64
#  6   Adjustment         993869 non-null  float64
#  7   Last Payment Date  991506 non-null  object
#  8   Item Name          993847 non-null  object
#  9   Item Desc          84 non-null      object
#  10  Quantity           993869 non-null  float64
#  11  Discount           993869 non-null  float64
#  12  Discount Amount    993869 non-null  float64
#  13  Item Total         993869 non-null  float64
#  14  Item Price         993869 non-null  float64
# ...

# %%
sns.barplot(x=df["Product ID"],y=df["Quantity"])
# Out:
# <Axes: xlabel='Product ID', ylabel='Quantity'>

# %%
sns.distplot(df["Quantity"])
# Out:
# C:\Users\Antino\AppData\Local\Temp\ipykernel_8304\2505815824.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Quantity"])
# <Axes: xlabel='Quantity', ylabel='Density'>

# %%
sns.distplot(df["Item Price"])
# Out:
# C:\Users\Antino\AppData\Local\Temp\ipykernel_8304\461462978.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Item Price"])
# <Axes: xlabel='Item Price', ylabel='Density'>

# %%
sns.jointplot(x=df["Quantity"], y=df["Discount"])

# %%
sns.jointplot(x=df["Quantity"], y=df["Discount"],kind='hex')

# %%
sns.pairplot(df[["Item Price","Discount","Product ID"]])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sns.pairplot(df[["Item Price","Discount","Product ID"]])
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:2144, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2142 diag_kws.setdefault("legend", False)
#    2143 if diag_kind == "hist":
# -> 2144     grid.map_diag(histplot, **diag_kws)
#    2145 elif diag_kind == "kde":
#    2146     diag_kws.setdefault("fill", True)
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:1507, in PairGrid.map_diag(self, func, **kwargs)
#    1505     plot_kwargs.setdefault("hue_order", self._hue_order)
#    1506     plot_kwargs.setdefault("palette", self._orig_palette)
# -> 1507     func(x=vector, **plot_kwargs)
# ...

# %%
sns.stripplot(x=df["Item Type"],y=df["Quantity"])
# Out:
# <Axes: xlabel='Item Type', ylabel='Quantity'>

# %%
sns.stripplot(x=df["Item Type"],y=df["Quantity"],jitter=True)
# Out:
# <Axes: xlabel='Item Type', ylabel='Quantity'>

# %%
sns.swarmplot(x=df["Quantity"],y=df["Discount"])
# Out:
# C:\Users\Antino\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 97.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Antino\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sns.swarmplot(x=df["Quantity"],y=df["Discount"])
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:2664, in swarmplot(data, x, y, hue, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, native_scale, formatter, legend, warn_thresh, ax, **kwargs)
#    2657     linewidth = size / 10
# ...

# %%
sns.boxplot(x=df["Quantity"], y=df["Discount"], hue=df["Item Type"])

# %%
sns.barplot(x=df["Quantity"], y=df["Discount"], hue=df["Item Type"])

# %%
sns.countplot(x=df["Item Type"])

# %%
sns.pointplot(x=df["Quantity"], y=df["Discount"], hue=df["Item Type"])

# %%
sns.lmplot(x=df["Quantity"],y=df["Discount"])

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >
