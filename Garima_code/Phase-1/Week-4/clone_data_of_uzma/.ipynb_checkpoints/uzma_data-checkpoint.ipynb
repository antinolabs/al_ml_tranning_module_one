# %%
import pandas as pd
import os
import glob
import numpy as np
from datetime import datetime, timedelta
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
# Define the path where your CSV files are located
path = 'C:/Users/Antino/Desktop/aimlgit/al_ml_tranning_module_one/Uzma_code/Invoices/*.csv'

# Get a list of all CSV file paths in the specified directory
file_paths = glob.glob(path)

# Initialize an empty list to store the data frames
dfs = []

# Iterate over the file paths
for file_path in file_paths:
    # Read each CSV file into a data frame
    df = pd.read_csv(file_path)
    # Append the data frame to the list
    dfs.append(df)

# Concatenate all data frames in the list vertically
combined_df = pd.concat(dfs, ignore_index=True)

# Write the combined data frame to a new CSV file
combined_df.to_csv('C:/Users/Antino/Desktop/al_ml_tranning_module_one/Uzma_code/combined.csv', index=False)

# %%
df = pd.read_csv('C:/Users/Antino/Desktop/al_ml_tranning_module_one/Uzma_code/combined.csv',low_memory=False)

# %%
df.head()
# Out:
#            Invoice ID Invoice Status         Customer ID    Due Date  \
# 0  209792000458527712         Closed  209792000285655627  2023-01-01
# 1  209792000458527712         Closed  209792000285655627  2023-01-01
# 2  209792000458527712         Closed  209792000285655627  2023-01-01
# 3  209792000458527712         Closed  209792000285655627  2023-01-01
# 4  209792000458527712         Closed  209792000285655627  2023-01-01
#
#    PurchaseOrder  SubTotal    Total  Balance  Adjustment  \
# 0            NaN   12394.5  12394.5      0.0         0.0
# 1            NaN   12394.5  12394.5      0.0         0.0
# 2            NaN   12394.5  12394.5      0.0         0.0
# 3            NaN   12394.5  12394.5      0.0         0.0
# 4            NaN   12394.5  12394.5      0.0         0.0
#
#    Expected Payment Date  ...    Product ID                SKU  \
# 0                    NaN  ...  2.097920e+17  FARMTHFINALCAT107
# 1                    NaN  ...  2.097920e+17   FARMTHFINALCAT94
# 2                    NaN  ...  2.097920e+17   FARMTHFINALCAT82
# 3                    NaN  ...  2.097920e+17   FARMTHFINALCAT54
# 4                    NaN  ...  2.097920e+17   FARMTHFINALCAT57
#
#                         Customer Name  Invoice Date  Invoice Number  Account  \
# 0  KINEMATIC FOODTECH PRIVATE LIMITED    2023-01-01      INV-082845    Sales
# 1  KINEMATIC FOODTECH PRIVATE LIMITED    2023-01-01      INV-082845    Sales
# 2  KINEMATIC FOODTECH PRIVATE LIMITED    2023-01-01      INV-082845    Sales
# 3  KINEMATIC FOODTECH PRIVATE LIMITED    2023-01-01      INV-082845    Sales
# 4  KINEMATIC FOODTECH PRIVATE LIMITED    2023-01-01      INV-082845    Sales
#
#    Account Code  Sales person  Item Type Usage Unit
# 0           NaN           NaN      goods       1 Kg
# 1           NaN           NaN      goods       1 Kg
# 2           NaN           NaN      goods       1 Kg
# 3           NaN           NaN      goods       1 Kg
# 4           NaN           NaN      goods         Kg
#
# [5 rows x 28 columns]

# %%
# using shape we can get rows and coloumn in data
df.shape
# Out:
# (693360, 28)

# %%
df.head()
# Out:
#            Invoice ID Invoice Status         Customer ID    Due Date  \
# 0  209792000458527712         Closed  209792000285655627  2023-01-01
# 1  209792000458527712         Closed  209792000285655627  2023-01-01
# 2  209792000458527712         Closed  209792000285655627  2023-01-01
# 3  209792000458527712         Closed  209792000285655627  2023-01-01
# 4  209792000458527712         Closed  209792000285655627  2023-01-01
#
#    PurchaseOrder  SubTotal    Total  Balance  Adjustment  \
# 0            NaN   12394.5  12394.5      0.0         0.0
# 1            NaN   12394.5  12394.5      0.0         0.0
# 2            NaN   12394.5  12394.5      0.0         0.0
# 3            NaN   12394.5  12394.5      0.0         0.0
# 4            NaN   12394.5  12394.5      0.0         0.0
#
#    Expected Payment Date  ...    Product ID                SKU  \
# 0                    NaN  ...  2.097920e+17  FARMTHFINALCAT107
# 1                    NaN  ...  2.097920e+17   FARMTHFINALCAT94
# 2                    NaN  ...  2.097920e+17   FARMTHFINALCAT82
# 3                    NaN  ...  2.097920e+17   FARMTHFINALCAT54
# 4                    NaN  ...  2.097920e+17   FARMTHFINALCAT57
#
#                         Customer Name  Invoice Date  Invoice Number  Account  \
# 0  KINEMATIC FOODTECH PRIVATE LIMITED    2023-01-01      INV-082845    Sales
# 1  KINEMATIC FOODTECH PRIVATE LIMITED    2023-01-01      INV-082845    Sales
# 2  KINEMATIC FOODTECH PRIVATE LIMITED    2023-01-01      INV-082845    Sales
# 3  KINEMATIC FOODTECH PRIVATE LIMITED    2023-01-01      INV-082845    Sales
# 4  KINEMATIC FOODTECH PRIVATE LIMITED    2023-01-01      INV-082845    Sales
#
#    Account Code  Sales person  Item Type Usage Unit
# 0           NaN           NaN      goods       1 Kg
# 1           NaN           NaN      goods       1 Kg
# 2           NaN           NaN      goods       1 Kg
# 3           NaN           NaN      goods       1 Kg
# 4           NaN           NaN      goods         Kg
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693360 entries, 0 to 693359
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Invoice ID             693360 non-null  int64
#  1   Invoice Status         693360 non-null  object
#  2   Customer ID            693360 non-null  int64
#  3   Due Date               693360 non-null  object
#  4   PurchaseOrder          0 non-null       float64
#  5   SubTotal               693360 non-null  float64
#  6   Total                  693360 non-null  float64
#  7   Balance                693360 non-null  float64
#  8   Adjustment             693360 non-null  float64
#  9   Expected Payment Date  0 non-null       float64
#  10  Last Payment Date      572071 non-null  object
#  11  Item Name              693343 non-null  object
#  12  Item Desc              2682 non-null    object
#  13  Quantity               693360 non-null  float64
#  14  Discount               693360 non-null  float64
#  15  Discount Amount        693360 non-null  float64
#  16  Item Total             693360 non-null  float64
#  17  Item Price             693360 non-null  float64
#  18  Product ID             693343 non-null  float64
#  19  SKU                    693343 non-null  object
#  20  Customer Name          693360 non-null  object
#  21  Invoice Date           693360 non-null  object
#  22  Invoice Number         693360 non-null  object
#  23  Account                693360 non-null  object
#  24  Account Code           0 non-null       float64
#  25  Sales person           0 non-null       float64
#  26  Item Type              693360 non-null  object
#  27  Usage Unit             693343 non-null  object
# dtypes: float64(14), int64(2), object(12)
# memory usage: 148.1+ MB

# %%
df.isnull().sum()
# Out:
# Invoice ID                    0
# Invoice Status                0
# Customer ID                   0
# Due Date                      0
# PurchaseOrder            693360
# SubTotal                      0
# Total                         0
# Balance                       0
# Adjustment                    0
# Expected Payment Date    693360
# Last Payment Date        121289
# Item Name                    17
# Item Desc                690678
# Quantity                      0
# Discount                      0
# Discount Amount               0
# Item Total                    0
# Item Price                    0
# Product ID                   17
# SKU                          17
# Customer Name                 0
# Invoice Date                  0
# Invoice Number                0
# Account                       0
# Account Code             693360
# Sales person             693360
# Item Type                     0
# Usage Unit                   17
# dtype: int64

# %%
df.describe()
# Out:
#          Invoice ID   Customer ID  PurchaseOrder       SubTotal  \
# count  6.933600e+05  6.933600e+05            0.0  693360.000000
# mean   2.097920e+17  2.097920e+17            NaN    3176.838594
# std    1.038913e+08  1.909196e+08            NaN    3768.932098
# min    2.097920e+17  2.097920e+17            NaN      13.600000
# 25%    2.097920e+17  2.097920e+17            NaN    1568.000000
# 50%    2.097920e+17  2.097920e+17            NaN    2439.500000
# 75%    2.097920e+17  2.097920e+17            NaN    3585.950000
# max    2.097920e+17  2.097920e+17            NaN   86193.500000
#
#                Total        Balance     Adjustment  Expected Payment Date  \
# count  693360.000000  693360.000000  693360.000000                    0.0
# mean     3173.905582     707.917484      -2.933012                    NaN
# std      3768.869519    2536.132622      83.014005                    NaN
# min         0.500000       0.000000  -10000.000000                    NaN
# 25%      1565.500000       0.000000       0.000000                    NaN
# 50%      2437.500000       0.000000       0.000000                    NaN
# 75%      3583.150000       0.000000       0.000000                    NaN
# max     86193.500000   71822.900000    1503.000000                    NaN
#
#             Quantity  Discount  Discount Amount     Item Total     Item Price  \
# count  693360.000000  693360.0         693360.0  693360.000000  693360.000000
# mean        3.555078       0.0              0.0     146.518705      64.921056
# std        11.567285       0.0              0.0     341.040419      49.103444
# min         0.050000       0.0              0.0       0.000000       0.000000
# 25%         0.500000       0.0              0.0      38.000000      32.000000
# 50%         1.000000       0.0              0.0      75.000000      55.000000
# 75%         3.000000       0.0              0.0     150.000000      85.000000
# max      3000.000000       0.0              0.0   21263.000000    1500.000000
#
#          Product ID  Account Code  Sales person
# count  6.933430e+05           0.0           0.0
# mean   2.097920e+17           NaN           NaN
# std    1.006360e+07           NaN           NaN
# min    2.097920e+17           NaN           NaN
# 25%    2.097920e+17           NaN           NaN
# 50%    2.097920e+17           NaN           NaN
# 75%    2.097920e+17           NaN           NaN
# max    2.097920e+17           NaN           NaN

# %%
reduced_data = df.drop(['Expected Payment Date','Account Code','Sales person','Account','PurchaseOrder','Invoice Date','Discount','Discount Amount','Adjustment'],axis=1)
reduced_data.head()
# Out:
#            Invoice ID Invoice Status         Customer ID    Due Date  \
# 0  209792000792779145        Overdue  209792000049944001  2023-06-01
# 1  209792000792779145        Overdue  209792000049944001  2023-06-01
# 2  209792000792779145        Overdue  209792000049944001  2023-06-01
# 3  209792000792779145        Overdue  209792000049944001  2023-06-01
# 4  209792000792779145        Overdue  209792000049944001  2023-06-01
#
#    SubTotal    Total  Balance Last Payment Date                   Item Name  \
# 0   1582.55  1582.55  1582.55               NaN  Cauliflower (600-900gm/pc)
# 1   1582.55  1582.55  1582.55               NaN             Mushroom Button
# 2   1582.55  1582.55  1582.55               NaN       Carrot Local - Medium
# 3   1582.55  1582.55  1582.55               NaN                Spring Onion
# 4   1582.55  1582.55  1582.55               NaN         Cabbage Local - Big
#
#   Item Desc  Quantity  Item Total  Item Price          Product ID  \
# 0       NaN       2.0       52.00        26.0  209792000054203622
# 1       NaN       6.0      228.00        38.0  209792000054203640
# 2       NaN       3.0      117.00        39.0  209792000054203883
# 3       NaN       1.0       65.00        65.0  209792000054203685
# 4       NaN       8.5      165.75        19.5  209792000054203937
#
#                  SKU          Customer Name Invoice Number Item Type  \
# 0   FARMTHFINALCAT41  GREEN ONION (MG ROAD)     INV-120959     goods
# 1   FARMTHFINALCAT79  GREEN ONION (MG ROAD)     INV-120959     goods
# 2   FARMTHFINALCAT39  GREEN ONION (MG ROAD)     INV-120959     goods
# 3  FARMTHFINALCAT102  GREEN ONION (MG ROAD)     INV-120959     goods
# 4   FARMTHFINALCAT29  GREEN ONION (MG ROAD)     INV-120959     goods
#
#               Usage Unit
# 0                   1 Pc
# 1  1 Pc (180 - 200 g/Pc)
# 2                   1 Kg
# 3                   1 Kg
# 4                   1 Kg

# %%
reduced_data.describe()
# Out:
#          Invoice ID   Customer ID      SubTotal         Total       Balance  \
# count  1.836000e+04  1.836000e+04  18360.000000  18360.000000  18360.000000
# mean   2.097920e+17  2.097920e+17   3868.128619   3868.128619   3796.259518
# std    1.950142e+06  2.358757e+08   3584.598809   3584.598809   3626.904619
# min    2.097920e+17  2.097920e+17     23.900000     23.900000      0.000000
# 25%    2.097920e+17  2.097920e+17   2146.800000   2146.800000   2023.000000
# 50%    2.097920e+17  2.097920e+17   3046.550000   3046.550000   3026.600000
# 75%    2.097920e+17  2.097920e+17   4199.650000   4199.650000   4154.000000
# max    2.097920e+17  2.097920e+17  35378.000000  35378.000000  35378.000000
#
#            Quantity    Item Total    Item Price    Product ID
# count  18360.000000  18360.000000  18360.000000  1.836000e+04
# mean       3.498278    166.724751     74.193236  2.097920e+17
# std        7.804660    313.830553     52.937722  9.315551e+06
# min        0.050000      3.500000      2.740000  2.097920e+17
# 25%        0.600000     47.000000     37.000000  2.097920e+17
# 50%        1.250000     92.500000     66.000000  2.097920e+17
# 75%        3.000000    185.000000     95.000000  2.097920e+17
# max      270.000000  14000.000000    650.000000  2.097920e+17

# %%
product_sales = reduced_data.groupby("Item Name")["Total"].sum()

# Find the product with the highest total sales
most_sold_product = product_sales.idxmax()

# Print the most sold product
print("The most sold product is:", most_sold_product)
# Out:
# The most sold product is: Coriander Hybrid

# %%
reduced_data['Item Type'].fillna(0,inplace=True)

# %%
reduced_data['Usage Unit'].fillna(reduced_data['Usage Unit'].sample(n=1).values[0], inplace=True)

# %%
reduced_data.corr()
# Out:
# C:\Users\Antino\AppData\Local\Temp\ipykernel_17192\2514683643.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   reduced_data.corr()
#              Invoice ID  Customer ID  SubTotal     Total   Balance  Quantity  \
# Invoice ID     1.000000     0.005230  0.069994  0.069994  0.079421  0.015342
# Customer ID    0.005230     1.000000 -0.056529 -0.056529 -0.046215  0.040984
# SubTotal       0.069994    -0.056529  1.000000  1.000000  0.991164  0.312179
# Total          0.069994    -0.056529  1.000000  1.000000  0.991164  0.312179
# Balance        0.079421    -0.046215  0.991164  0.991164  1.000000  0.307677
# Quantity       0.015342     0.040984  0.312179  0.312179  0.307677  1.000000
# Item Total     0.015393     0.023105  0.385858  0.385858  0.381329  0.730708
# Item Price     0.009709    -0.017548  0.020850  0.020850  0.024161 -0.224680
# Product ID    -0.004086     0.046870 -0.005764 -0.005764 -0.004838 -0.009394
#
#              Item Total  Item Price  Product ID
# Invoice ID     0.015393    0.009709   -0.004086
# Customer ID    0.023105   -0.017548    0.046870
# SubTotal       0.385858    0.020850   -0.005764
# Total          0.385858    0.020850   -0.005764
# Balance        0.381329    0.024161   -0.004838
# Quantity       0.730708   -0.224680   -0.009394
# Item Total     1.000000    0.032268    0.000082
# Item Price     0.032268    1.000000    0.028280
# Product ID     0.000082    0.028280    1.000000

# %%
sns.heatmap(reduced_data.corr(),cmap='coolwarm', annot=True)
# Out:
# C:\Users\Antino\AppData\Local\Temp\ipykernel_17192\1380860630.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(reduced_data.corr(),cmap='coolwarm', annot=True)
# <Axes: >

# %%
# Group the data by customer ID and calculate the count of purchases
customer_purchase_count = reduced_data.groupby("Customer ID").size()

# Find the customer with the highest purchase count
customer_with_most_purchases = customer_purchase_count.idxmax()

# Print the customer with the highest purchase count
print("The customer who purchases most frequently is:", customer_with_most_purchases)
# Out:
# The customer who purchases most frequently is: 209792000007190494

# %%
# Group the data by customer ID and calculate the count of purchases
customer_purchase_count = reduced_data.groupby("Customer ID").size()

# Find the customer with the highest purchase count
customer_with_most_purchases = customer_purchase_count.idxmax()

# Filter the data for the customer with the highest purchase count
customer_data = df[df["Customer ID"] == customer_with_most_purchases]

# Get the customer name
customer_name = customer_data["Customer Name"].iloc[0]

# Get the number of times the customer comes for shopping
purchase_count = customer_purchase_count.loc[customer_with_most_purchases]

# Get the unique invoice numbers for the customer
invoice_numbers = customer_data["Invoice Number"].unique()

# Print the customer information
print("Customer Name:", customer_name)
print("Number of times the customer comes for shopping:", purchase_count)
print("Invoice Numbers:")
for invoice_number in invoice_numbers:
    print(invoice_number)
# Out:
# Customer Name: JOOK HOSPITALITY PRIVATE LIMITED (SARJAPUR)
# Number of times the customer comes for shopping: 170
# Invoice Numbers:
# INV-121010
# INV-121319
# INV-121588
# INV-121826

# %%
item_names = reduced_data["Item Name"].value_counts().index
print(item_names)
# Out:
# Index(['Coriander Hybrid', 'Tomato Hybrid', 'Carrot Local',
#        'Mint Leaves (Pudhina )', 'Onion', 'Palak', 'Beans Haricot',
#        'Broccoli  - Big', 'Capsicum Green - Big', 'Garlic Peeled',
#        ...
#        'Pumpkin White (Ash Gourd) (Kg)', 'Pear', 'Tomato Local',
#        'Amaranth Red', 'Banana Yelakki', 'Lemon (medium, spots, 20-30 pcs/kg)',
#        'Basale Soppu', 'Arive Soppu', 'Dragon Fruit', 'Sage'],
#       dtype='object', length=133)

# %%
item_values= reduced_data["Item Name"].value_counts().values

# %%
plt.pie(item_values,labels=item_names)
# Out:
# ([<matplotlib.patches.Wedge at 0x2316c6d1420>,
#   <matplotlib.patches.Wedge at 0x2316c547610>,
#   <matplotlib.patches.Wedge at 0x2316c6d1ab0>,
#   <matplotlib.patches.Wedge at 0x2316c6d1f30>,
#   <matplotlib.patches.Wedge at 0x2316c6d2320>,
#   <matplotlib.patches.Wedge at 0x2316c6d27d0>,
#   <matplotlib.patches.Wedge at 0x2316c6d2c50>,
#   <matplotlib.patches.Wedge at 0x2316c6d30d0>,
#   <matplotlib.patches.Wedge at 0x2316c6d3550>,
#   <matplotlib.patches.Wedge at 0x2316c6d39d0>,
#   <matplotlib.patches.Wedge at 0x2316c6d13f0>,
#   <matplotlib.patches.Wedge at 0x2316c6a42e0>,
#   <matplotlib.patches.Wedge at 0x2316c6a4760>,
#   <matplotlib.patches.Wedge at 0x2316c6a4be0>,
#   <matplotlib.patches.Wedge at 0x2316c6a5060>,
#   <matplotlib.patches.Wedge at 0x2316c6a54e0>,
#   <matplotlib.patches.Wedge at 0x2316c6a5960>,
#   <matplotlib.patches.Wedge at 0x2316c6a5de0>,
#   <matplotlib.patches.Wedge at 0x2316c6a6260>,
#   <matplotlib.patches.Wedge at 0x2316c6a66e0>,
#   <matplotlib.patches.Wedge at 0x2316c6a6b60>,
#   <matplotlib.patches.Wedge at 0x2316c6a6fe0>,
#   <matplotlib.patches.Wedge at 0x2316c6a7460>,
#   <matplotlib.patches.Wedge at 0x2316c6a78e0>,
#   <matplotlib.patches.Wedge at 0x2316c6a7d60>,
#   <matplotlib.patches.Wedge at 0x2316c6eec80>,
#   <matplotlib.patches.Wedge at 0x2316c6743a0>,
#   <matplotlib.patches.Wedge at 0x2316c674820>,
#   <matplotlib.patches.Wedge at 0x2316c674ca0>,
#   <matplotlib.patches.Wedge at 0x2316c675120>,
#   <matplotlib.patches.Wedge at 0x2316c6755a0>,
#   <matplotlib.patches.Wedge at 0x2316c675a20>,
#   <matplotlib.patches.Wedge at 0x2316c675ed0>,
#   <matplotlib.patches.Wedge at 0x2316c676350>,
#   <matplotlib.patches.Wedge at 0x2316c6767d0>,
#   <matplotlib.patches.Wedge at 0x2316c676c50>,
#   <matplotlib.patches.Wedge at 0x2316c6770d0>,
#   <matplotlib.patches.Wedge at 0x2316c677550>,
#   <matplotlib.patches.Wedge at 0x2316c6779d0>,
#   <matplotlib.patches.Wedge at 0x2316c677e50>,
#   <matplotlib.patches.Wedge at 0x231178dc310>,
#   <matplotlib.patches.Wedge at 0x231178dc790>,
#   <matplotlib.patches.Wedge at 0x231178dcc10>,
#   <matplotlib.patches.Wedge at 0x231178dd090>,
#   <matplotlib.patches.Wedge at 0x231178dd510>,
#   <matplotlib.patches.Wedge at 0x231178dd990>,
#   <matplotlib.patches.Wedge at 0x231178dde10>,
#   <matplotlib.patches.Wedge at 0x231178de290>,
#   <matplotlib.patches.Wedge at 0x231178de710>,
#   <matplotlib.patches.Wedge at 0x231178deb90>,
#   <matplotlib.patches.Wedge at 0x231178df010>,
#   <matplotlib.patches.Wedge at 0x231178df490>,
#   <matplotlib.patches.Wedge at 0x231178df910>,
#   <matplotlib.patches.Wedge at 0x231178dfd90>,
#   <matplotlib.patches.Wedge at 0x23117904250>,
#   <matplotlib.patches.Wedge at 0x231179046d0>,
#   <matplotlib.patches.Wedge at 0x23117904b50>,
#   <matplotlib.patches.Wedge at 0x23117904fd0>,
#   <matplotlib.patches.Wedge at 0x23117905450>,
#   <matplotlib.patches.Wedge at 0x231179058d0>,
#   <matplotlib.patches.Wedge at 0x23117905d50>,
#   <matplotlib.patches.Wedge at 0x231179061d0>,
#   <matplotlib.patches.Wedge at 0x23117906650>,
#   <matplotlib.patches.Wedge at 0x23117906ad0>,
#   <matplotlib.patches.Wedge at 0x23117906f50>,
#   <matplotlib.patches.Wedge at 0x231179073d0>,
#   <matplotlib.patches.Wedge at 0x23117907850>,
#   <matplotlib.patches.Wedge at 0x23117907cd0>,
#   <matplotlib.patches.Wedge at 0x23117934190>,
#   <matplotlib.patches.Wedge at 0x23117934610>,
#   <matplotlib.patches.Wedge at 0x23117934a90>,
#   <matplotlib.patches.Wedge at 0x23117934f10>,
#   <matplotlib.patches.Wedge at 0x23117935390>,
#   <matplotlib.patches.Wedge at 0x23117935810>,
#   <matplotlib.patches.Wedge at 0x23117935c90>,
#   <matplotlib.patches.Wedge at 0x23117936110>,
#   <matplotlib.patches.Wedge at 0x23117936590>,
#   <matplotlib.patches.Wedge at 0x23117936a10>,
#   <matplotlib.patches.Wedge at 0x23117936e90>,
#   <matplotlib.patches.Wedge at 0x23117937310>,
#   <matplotlib.patches.Wedge at 0x23117937790>,
#   <matplotlib.patches.Wedge at 0x23117937c10>,
#   <matplotlib.patches.Wedge at 0x231179740d0>,
#   <matplotlib.patches.Wedge at 0x23117974550>,
#   <matplotlib.patches.Wedge at 0x231179749d0>,
#   <matplotlib.patches.Wedge at 0x23117974e50>,
#   <matplotlib.patches.Wedge at 0x231179752d0>,
#   <matplotlib.patches.Wedge at 0x23117975750>,
#   <matplotlib.patches.Wedge at 0x23117975bd0>,
#   <matplotlib.patches.Wedge at 0x23117976050>,
#   <matplotlib.patches.Wedge at 0x231179764d0>,
#   <matplotlib.patches.Wedge at 0x23117976950>,
#   <matplotlib.patches.Wedge at 0x23117976dd0>,
#   <matplotlib.patches.Wedge at 0x23117977250>,
#   <matplotlib.patches.Wedge at 0x231179776d0>,
#   <matplotlib.patches.Wedge at 0x23117977b50>,
#   <matplotlib.patches.Wedge at 0x23117977fd0>,
#   <matplotlib.patches.Wedge at 0x231179a8490>,
#   <matplotlib.patches.Wedge at 0x231179a8910>,
#   <matplotlib.patches.Wedge at 0x231179a8d90>,
#   <matplotlib.patches.Wedge at 0x231179a9210>,
#   <matplotlib.patches.Wedge at 0x231179a9690>,
#   <matplotlib.patches.Wedge at 0x231179a9b10>,
#   <matplotlib.patches.Wedge at 0x231179a9f90>,
#   <matplotlib.patches.Wedge at 0x231179aa410>,
#   <matplotlib.patches.Wedge at 0x231179aa890>,
#   <matplotlib.patches.Wedge at 0x231179aad10>,
#   <matplotlib.patches.Wedge at 0x231179ab190>,
#   <matplotlib.patches.Wedge at 0x231179ab610>,
#   <matplotlib.patches.Wedge at 0x231179aba90>,
#   <matplotlib.patches.Wedge at 0x231179abf10>,
#   <matplotlib.patches.Wedge at 0x2310003c3d0>,
#   <matplotlib.patches.Wedge at 0x2310003c850>,
#   <matplotlib.patches.Wedge at 0x2310003ccd0>,
#   <matplotlib.patches.Wedge at 0x2310003d150>,
#   <matplotlib.patches.Wedge at 0x2310003d5d0>,
#   <matplotlib.patches.Wedge at 0x2310003da50>,
#   <matplotlib.patches.Wedge at 0x2310003ded0>,
#   <matplotlib.patches.Wedge at 0x2310003e350>,
#   <matplotlib.patches.Wedge at 0x2310003e7d0>,
#   <matplotlib.patches.Wedge at 0x2310003ec50>,
#   <matplotlib.patches.Wedge at 0x2310003f0d0>,
#   <matplotlib.patches.Wedge at 0x2310003f550>,
#   <matplotlib.patches.Wedge at 0x2310003f9d0>,
#   <matplotlib.patches.Wedge at 0x2310003fe50>,
#   <matplotlib.patches.Wedge at 0x23100078310>,
#   <matplotlib.patches.Wedge at 0x231000787c0>,
#   <matplotlib.patches.Wedge at 0x23100078c40>,
#   <matplotlib.patches.Wedge at 0x231000790c0>,
#   <matplotlib.patches.Wedge at 0x23100079540>,
#   <matplotlib.patches.Wedge at 0x231000799c0>,
#   <matplotlib.patches.Wedge at 0x23100079e40>,
#   <matplotlib.patches.Wedge at 0x2310007a2c0>],
#  [Text(1.0934517223288156, 0.11984711484281622, 'Coriander Hybrid'),
#   Text(1.0450515273416885, 0.3433180816688868, 'Tomato Hybrid'),
#   Text(0.9587783743067646, 0.5392068517384379, 'Carrot Local'),
#   Text(0.8443402660161253, 0.7050457539648182, 'Mint Leaves (Pudhina )'),
#   Text(0.710089690193949, 0.8401027507872249, 'Onion'),
#   Text(0.559589072046212, 0.9470269639489995, 'Palak'),
#   Text(0.39999717208395086, 1.0246961804968546, 'Beans Haricot'),
#   Text(0.23385523634288072, 1.0748542824192568, 'Broccoli  - Big'),
#   Text(0.06283183951232424, 1.0982040611578059, 'Capsicum Green - Big'),
#   Text(-0.10842762989318079, 1.0946430692585358, 'Garlic Peeled'),
#   Text(-0.2732307229367465, 1.065525678734897, 'Spring Onion'),
#   Text(-0.42442720250647176, 1.014820944685579, 'Potato'),
#   Text(-0.5620179616078106, 0.9455875479458271, 'Lemon Yellow'),
#   Text(-0.686973416605236, 0.8591085640812395, 'Mushroom Button'),
#   Text(-0.7959657444139576, 0.7592354929266245, 'Lettuce Iceberg'),
#   Text(-0.8877008152079686, 0.6496054669405948, 'Cauliflower (600-900gm/pc)'),
#   Text(-0.9622641296063655, 0.5329612977251762, 'Cabbage Local - Big'),
#   Text(-1.0191956591380782, 0.41381180311114674, 'Basil Leaves'),
#   Text(-1.0602947433300614, 0.29287379067891905, 'Cucumber Indian - Medium'),
#   Text(-1.0868952636757507, 0.16928876453923428, 'Ginger'),
#   Text(-1.0989694003979864, 0.0476052201852954, 'Zucchini Yellow - Medium'),
#   Text(-1.097736237894516, -0.07053475748306806, 'Chilli Long Green'),
#   Text(-1.0852539587050898, -0.17951001396839034, 'Chilli Small Spicy (Akash Chilli )'),
#   Text(-1.065009512965511, -0.2752357849062602, 'Capsicum Red - Big'),
#   Text(-1.0380939188978586, -0.36381453454650015, 'Celery'),
#   Text(-1.0042866031262192, -0.44878549306010324, 'Parsley'),
#   Text(-0.9643541561369098, -0.5291701631247445, 'Capsicum Red (Medium, misshapes, irregular size)'),
#   Text(-0.9191400030862928, -0.6043026185004743, 'Zucchini Green - Medium'),
#   Text(-0.8686626661658504, -0.6748519633294672, 'Pineapple'),
#   Text(-0.8137968492665252, -0.7400909998938486, 'Capsicum Yellow (Medium, misshapes, irregular size)'),
#   Text(-0.7560970691988798, -0.7989475714644013, 'Cucumber English'),
#   Text(-0.696485882316754, -0.8514149492071729, 'Apple'),
#   Text(-0.6352439194604852, -0.8980340543590096, 'Lettuce Green'),
#   Text(-0.5721784991335028, -0.9394741960955246, 'Lemon (medium, spots, 25-40 pcs/kg)'),
#   Text(-0.5077565092015945, -0.9757988150041028, 'Capsicum Green (Medium, misshapes, irregular size)'),
#   Text(-0.44207361199226686, -1.0072591134261883, 'Baby Corn Peeled - Packet'),
#   Text(-0.3753376646754047, -1.0339833835589496, 'Orange Imported'),
#   Text(-0.30988938995125936, -1.0554470929400661, 'Beetroot'),
#   Text(-0.24652907385377687, -1.072018384051691, 'Tomato Hybrid (Mix of medium, semi ripe 12-16 pcs/kg)'),
#   Text(-0.18582067055484403, -1.084191255450139, 'Ginger (Small)'),
#   Text(-0.12695436964486786, -1.0926493435810385, 'Curry Leaves'),
#   Text(-0.06865628420352389, -1.0978553250038754, 'Watermelon Kiran'),
#   Text(-0.01148130774423607, -1.0999400799918522, 'Onion  - Medium'),
#   Text(0.044972480182392416, -1.0990802864332727, 'Chinese Cabbage'),
#   Text(0.10018320309667227, -1.0954283754848106, 'Capsicum Yellow - Big'),
#   Text(0.15439504211162067, -1.0891107248445178, 'Banana Leaf'),
#   Text(0.20767230048896962, -1.0802185962154232, 'Cauliflower (Medium, approx 300-500gm/pc)'),
#   Text(0.25953437922776257, -1.0689442950869144, 'Leeks'),
#   Text(0.309889405391585, -1.0554470884066383, 'Bok Choy  (Pok Choy )'),
#   Text(0.35830294272674246, -1.040009135168224, 'Ladies Finger - Okra/Bhindi'),
#   Text(0.4052520061928962, -1.022629361732115, 'Pomegranate'),
#   Text(0.44930096352339827, -1.004056096130563, 'Cabbage Local - Medium'),
#   Text(0.49014370289479314, -0.9847634997869189, 'Lemon Green ( Lime )'),
#   Text(0.5298300810964394, -0.9639917453823662, 'Lettuce Romaine'),
#   Text(0.5676708435558185, -0.9422047619157025, 'Cabbage Red'),
#   Text(0.6036733733105161, -0.9195534015792136, 'Cherry Tomato'),
#   Text(0.6384667485278839, -0.8957456173625591, 'Radish White'),
#   Text(0.6712789782394122, -0.8714267228940429, 'Red Chilli'),
#   Text(0.7020072051159092, -0.8468682801742842, 'Muskmelon'),
#   Text(0.7312754554255082, -0.8217275754726839, 'Watermelon Kiran (kg)'),
#   Text(0.759235509228682, -0.7959657288641667, 'Brinjal Big  - Bottle Black (Bharta Baingan / Eggplant )'),
#   Text(0.7853666417210488, -0.7701942859251826, 'Carrot Local - Medium'),
#   Text(0.8098596646111967, -0.7443972888423492, 'Banana Robusta'),
#   Text(0.8328913135978364, -0.7185346614696265, 'Coconut'),
#   Text(0.8539121460209501, -0.6934219832669685, 'Garlic Whole'),
#   Text(0.8730323093763851, -0.6691894999063689, 'Cucumber Indian (Big, misshapes)'),
#   Text(0.8904715416686797, -0.6458021628008109, 'Papaya Ripe (kg)'),
#   Text(0.9067519787986622, -0.6227365807022345, 'Potato  - (Medium, 17-20 pcs/kg)'),
#   Text(0.922229969228637, -0.5995764203640329, 'Bitter Gourd  (Karela )'),
#   Text(0.9367220617376897, -0.5766730261195612, 'Rocket Lettuce - Arugula'),
#   Text(0.9499819200509939, -0.5545577982286674, 'Mango Ripe'),
#   Text(0.9619904163017179, -0.5334551892555246, 'Raw Mango'),
#   Text(0.9730039610148129, -0.51309189415687, 'Brinjal Small  - Purple Stripes (Varikatri )'),
#   Text(0.9831647982860778, -0.49334265922490006, 'Pumpkin Red (Kadoo) (Kg)'),
#   Text(0.992762770131608, -0.4737320785429421, 'Lettuce Red'),
#   Text(1.0017364782542457, -0.454449148018545, 'Drumstick'),
#   Text(1.0100377203892779, -0.43568773610331424, 'Lemongrass'),
#   Text(1.0179162893291802, -0.4169489512138301, 'Baby Potato'),
#   Text(1.0253791120099016, -0.3982432380515532, 'Bottle Gourd  (Lauki) - Big, patches'),
#   Text(1.032368322190098, -0.3797573532380932, 'Sweet Potato'),
#   Text(1.0385289485084508, -0.3625708525377237, 'Rosemary'),
#   Text(1.0439891603200047, -0.3465351831118043, 'Chow Chow'),
#   Text(1.0490886482156603, -0.33077637186630954, 'Bottle Gourd  (Lauki ) - Medium'),
#   Text(1.0537884658632175, -0.31548354824562014, 'Ridge Gourd'),
#   Text(1.0582139993852102, -0.3003050640684542, 'Pumpkin Red (Kadoo) (Pc)'),
#   Text(1.062372125160016, -0.28524632807976935, 'Lotus Stem (Kamal Kakdi)'),
#   Text(1.06622346490116, -0.2704949590919679, 'Dill leaves'),
#   Text(1.0697385921042444, -0.25624079410357153, 'Green Apple'),
#   Text(1.0729388292873043, -0.242491790804532, 'Beans Long  - Cowpea (Karamani )'),
#   Text(1.07588403269967, -0.22907105487576543, 'Thyme'),
#   Text(1.0786244615466491, -0.21579914493158048, 'Cauliflower (Kg)'),
#   Text(1.0810275363560147, -0.20341943279845612, 'Kiwi (Box)'),
#   Text(1.0831247117902798, -0.19193972676135443, 'Methi  (Fenugreek )'),
#   Text(1.0850690940469774, -0.1806240879397654, 'Avocado  (Butter fruit )'),
#   Text(1.0867791396494844, -0.170032648696439, 'Coccinia  (Ivy Gourd )'),
#   Text(1.0882764316752174, -0.16016993556924497, 'Red Radish'),
#   Text(1.0896584868066277, -0.15048050415349626, 'Bajji Chilli'),
#   Text(1.0909542741641407, -0.14077915926369539, 'Zucchini Yellow - Big, misshape'),
#   Text(1.0921412482787292, -0.13125354779273357, 'Asparagus'),
#   Text(1.0932033331401112, -0.12209206530872979, 'Papaya Ripe'),
#   Text(1.0941498593964945, -0.1132964482348466, 'Knol Khol'),
#   Text(1.094989795616989, -0.10486823873158577, 'American Sweet Corn'),
#   Text(1.095748293631859, -0.09662130718878417, 'Cucumber Sambar/Mangalore'),
#   Text(1.09642954374505, -0.0885565107884338, 'Ridge Gourd (Farm, Misshape)'),
#   Text(1.097023828514236, -0.08086235015115792, 'Banana Raw'),
#   Text(1.0975390177781315, -0.07353981543772439, 'Snake Gourd (Kg)'),
#   Text(1.097982606202874, -0.06658976254609228, 'Brinjal Long Green'),
#   Text(1.0983514262523406, -0.06020086751409498, 'Papaya Raw'),
#   Text(1.098645984004874, -0.0545619082324144, 'Onion Sambar Peeled (Kg)'),
#   Text(1.0988863336361605, -0.0494856115217082, 'curry leaves'),
#   Text(1.0990879665358722, -0.04478439254965853, 'Galangal (Thai Ginger)'),
#   Text(1.099262612321651, -0.04027045010650061, 'Pumpkin White (Ash Gourd) (Pc)'),
#   Text(1.0994187194727025, -0.035755828517926073, 'Jackfruit'),
#   Text(1.0995509236559378, -0.03142874937656052, 'Beans White'),
#   Text(1.0996567584363561, -0.027477511263676847, 'Frozen Green Peas'),
#   Text(1.0997402790118425, -0.02390227434691332, 'Zucchini Green - Big, misshape'),
#   Text(1.0998051550390475, -0.020703162790662727, 'Gongura Soppu'),
#   Text(1.0998546703577594, -0.017880271033311298, 'Arbi  (Colocasia )'),
#   Text(1.0998943475546585, -0.015245465467226153, 'Amaranth Green'),
#   Text(1.0999233328180889, -0.012986990503879378, 'Sweet Lime'),
#   Text(1.099943944713057, -0.011104885820200533, 'Parwal'),
#   Text(1.0999597418832945, -0.00941096360826805, 'Capsicum Green (Medium, misshapes, irregular size)x'),
#   Text(1.0999715938344474, -0.007905236068949094, 'Yam'),
#   Text(1.099980273481144, -0.00658771222414409, 'Pumpkin White (Ash Gourd) (Kg)'),
#   Text(1.0999864571375693, -0.005458398477463017, 'Pear'),
#   Text(1.0999914813648366, -0.004329078977414427, 'Tomato Local'),
#   Text(1.099994782541984, -0.003387975857883593, 'Amaranth Red'),
#   Text(1.0999968437648158, -0.0026350915436631245, 'Banana Yelakki'),
#   Text(1.099998389680909, -0.0018822059950023594, 'Lemon (medium, spots, 20-30 pcs/kg)'),
#   Text(1.0999992109474865, -0.00131754123557514, 'Basale Soppu'),
#   Text(1.099999597424843, -0.000941097860558811, 'Arive Soppu'),
#   Text(1.0999998550751888, -0.0005646543753243515, 'Dragon Fruit'),
#   Text(1.0999999838984935, -0.00018821082396108536, 'Sage')])

# %%
#top 10 selling product
plt.pie(item_values[:10],labels=item_names[:10],autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x231000f5b40>,
#   <matplotlib.patches.Wedge at 0x231000f5a50>,
#   <matplotlib.patches.Wedge at 0x231000f6830>,
#   <matplotlib.patches.Wedge at 0x231000f6e90>,
#   <matplotlib.patches.Wedge at 0x231000f7520>,
#   <matplotlib.patches.Wedge at 0x231000f7bb0>,
#   <matplotlib.patches.Wedge at 0x23100eb8280>,
#   <matplotlib.patches.Wedge at 0x23100eb8910>,
#   <matplotlib.patches.Wedge at 0x23100eb8fa0>,
#   <matplotlib.patches.Wedge at 0x23100eb95d0>],
#  [Text(1.016299860001579, 0.42087360877200564, 'Coriander Hybrid'),
#   Text(0.45779601876079784, 1.000211380262574, 'Tomato Hybrid'),
#   Text(-0.29520321159872864, 1.0596485567686094, 'Carrot Local'),
#   Text(-0.8827021711188263, 0.6563816550621372, 'Mint Leaves (Pudhina )'),
#   Text(-1.099859197761958, 0.017599576654634987, 'Onion'),
#   Text(-0.9150629432875614, -0.6104586880550603, 'Palak'),
#   Text(-0.42992541873834894, -1.0125038934851833, 'Beans Haricot'),
#   Text(0.1822663264462383, -1.0847944442353092, 'Broccoli  - Big'),
#   Text(0.7347011740362285, -0.8186661009653372, 'Capsicum Green - Big'),
#   Text(1.0575328675541857, -0.3026949521260986, 'Garlic Peeled')],
#  [Text(0.5543453781826794, 0.22956742296654847, '12.50%'),
#   Text(0.24970691932407152, 0.5455698437795857, '11.34%'),
#   Text(-0.1610199335993065, 0.5779901218737868, '10.97%'),
#   Text(-0.4814739115193597, 0.35802635730662025, '10.03%'),
#   Text(-0.5999231987792497, 0.009599769084346356, '9.81%'),
#   Text(-0.49912524179321527, -0.33297746621185104, '9.42%'),
#   Text(-0.23450477385728122, -0.5522748509919181, '9.07%'),
#   Text(0.0994179962434027, -0.5917060604919868, '9.01%'),
#   Text(0.4007460949288518, -0.44654514598109296, '8.97%'),
#   Text(0.5768361095750104, -0.16510633752332649, '8.87%')])

# %%
#least selling products
plt.pie(item_values[-10:],labels=item_names[-10:],autopct="%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x23100f0ce80>,
#   <matplotlib.patches.Wedge at 0x23100f0cd90>,
#   <matplotlib.patches.Wedge at 0x23100f0db70>,
#   <matplotlib.patches.Wedge at 0x23100f0df30>,
#   <matplotlib.patches.Wedge at 0x23100f0e5c0>,
#   <matplotlib.patches.Wedge at 0x23100f0ec50>,
#   <matplotlib.patches.Wedge at 0x23100f0f2e0>,
#   <matplotlib.patches.Wedge at 0x23100f0f970>,
#   <matplotlib.patches.Wedge at 0x23100f3c040>,
#   <matplotlib.patches.Wedge at 0x23100f3c6d0>],
#  [Text(0.9674211366466224, 0.5235421132720434, 'Pumpkin White (Ash Gourd) (Kg)'),
#   Text(0.09083734484335818, 1.0962429369358824, 'Pear'),
#   Text(-0.868054493749272, 0.6756340695092983, 'Tomato Local'),
#   Text(-1.0849974547093206, -0.18105392366445883, 'Amaranth Red'),
#   Text(-0.7450098185180601, -0.8092962191383866, 'Banana Yelakki'),
#   Text(-0.09083739616219376, -1.0962429326834782, 'Lemon (medium, spots, 20-30 pcs/kg)'),
#   Text(0.44186486411638326, -1.007350704501372, 'Basale Soppu'),
#   Text(0.7450096480315366, -0.8092963760822891, 'Arive Soppu'),
#   Text(0.9674210753746777, -0.5235422264926701, 'Dragon Fruit'),
#   Text(1.0849974165684402, -0.18105415223024032, 'Sage')],
#  [Text(0.5276842563527031, 0.28556842542111455, '15.79%'),
#   Text(0.04954764264183172, 0.5979506928741176, '15.79%'),
#   Text(-0.4734842693177847, 0.36852767427779903, '15.79%'),
#   Text(-0.5918167934778112, -0.09875668563515935, '10.53%'),
#   Text(-0.4063689919189418, -0.4414343013482108, '10.53%'),
#   Text(-0.04954767063392386, -0.5979506905546245, '10.53%'),
#   Text(0.2410171986089363, -0.549464020637112, '5.26%'),
#   Text(0.40636889892629263, -0.4414343869539758, '5.26%'),
#   Text(0.5276842229316423, -0.2855684871778201, '5.26%'),
#   Text(0.5918167726736946, -0.0987568103074038, '5.26%')])

# %%
quantity = reduced_data['Quantity']
item_price = reduced_data['Item Price']

# Calculate the correlation coefficient
correlation = quantity.corr(item_price)

print("Correlation coefficient:", correlation)
# Out:
# Correlation coefficient: -0.22467969534941376

# %%
reduced_data.groupby(['Invoice ID','Customer Name']).size()
# Out:
# Invoice ID          Customer Name
# 209792000792758831  FRESH MENU BELLANDUR                                                                       38
# 209792000792758921  FRESH MENU KASAVANAHALLI                                                                   28
# 209792000792758993  FRESH MENU MTH                                                                             44
# 209792000792779145  GREEN ONION (MG ROAD)                                                                      10
# 209792000792779187  JOOK HOSPITALITY (BELL ROAD)                                                               29
#                                                                                                                ..
# 209792000798664693  INFINITUM HOSPITALITY(TIPSY BULL INDRANAGAR)                                                7
# 209792000798664797  PURABHI HOSPITALITY PVT LTD( BELLANDUR)                                                     5
# 209792000798664819  RED APPLE KITCHEN CONSULTANCY PVT LTD (TOSCANO MIRAYA ROSE W/F)                             8
# 209792000798664863  RED APPLE KITCHEN CONSULTANCY PVT LTD (TOSCANO SHANTHI NIKETHAN FOURM MALL)                 3
# 209792000798664883  RED APPLE KITCHEN CONSULTANCY PVT LTD (COLLAGE BY TOSCANO NEIGHBOURHOOD FORUM MALL W/F)     8
# Length: 965, dtype: int64

# %%
reduced_data.groupby(['Invoice ID','Customer Name']).size().reset_index().rename(columns={0:"Count"})
# Out:
#              Invoice ID                                      Customer Name  \
# 0    209792000792758831                               FRESH MENU BELLANDUR
# 1    209792000792758921                           FRESH MENU KASAVANAHALLI
# 2    209792000792758993                                     FRESH MENU MTH
# 3    209792000792779145                              GREEN ONION (MG ROAD)
# 4    209792000792779187                       JOOK HOSPITALITY (BELL ROAD)
# ..                  ...                                                ...
# 960  209792000798664693       INFINITUM HOSPITALITY(TIPSY BULL INDRANAGAR)
# 961  209792000798664797            PURABHI HOSPITALITY PVT LTD( BELLANDUR)
# 962  209792000798664819  RED APPLE KITCHEN CONSULTANCY PVT LTD (TOSCANO...
# 963  209792000798664863  RED APPLE KITCHEN CONSULTANCY PVT LTD (TOSCANO...
# 964  209792000798664883  RED APPLE KITCHEN CONSULTANCY PVT LTD (COLLAGE...
#
#      Count
# 0       38
# 1       28
# 2       44
# 3       10
# 4       29
# ..     ...
# 960      7
# 961      5
# 962      8
# 963      3
# 964      8
#
# [965 rows x 3 columns]

# %%
# Hypothesis: There is a correlation between the customer ID and the total invoice amount.

# Null hypothesis (H0): There is not a correlation between the customer ID and the total invoice amount.

# Alternative hypothesis (H1): There is a correlation between the customer ID and the total invoice amount.


# Extract the relevant columns
customer_id = reduced_data['Customer ID']
invoice_amount = reduced_data['Total']
min_length = min(len(customer_id), len(invoice_amount))
customer_id = customer_id[:min_length]
invoice_amount = invoice_amount[:min_length]

# Calculate the Pearson correlation coefficient and p-value
correlation, p_value = stats.pearsonr(customer_id, invoice_amount)

# Define the significance level
alpha = 0.05

# Check the p-value against the significance level to make a decision
if p_value < alpha:
    print("Reject the null hypothesis.")
    print("There is a correlation between the customer ID and the total invoice amount.")
else:
    print("Fail to reject the null hypothesis.")
    print("There is not a correlation between the customer ID and the total invoice amount.")
# Out:
# Reject the null hypothesis.
# There is a correlation between the customer ID and the total invoice amount.

# %%
# Hypothesis: The total invoice amount varies based on the day of the week.

# Null hypothesis (H0): The total invoice amount is the same for all days of the week.

# Alternative hypothesis (H1): The total invoice amount varies based on the day of the week.

# To test this hypothesis, you can use a statistical test such as the Kruskal-Wallis test, which is a non-parametric test used to compare multiple independent groups. Here's an example of how you can perform the test:


# Extract the relevant columns
day_of_week = pd.to_datetime(reduced_data['Due Date']).dt.dayofweek
invoice_total = reduced_data['Total']

# Create a list to store invoice totals for each day of the week
totals_by_day = []

# Iterate over the data and calculate invoice totals for each day of the week
for day in range(7):
    totals_by_day.append(invoice_total[day_of_week == day])

# Perform the Kruskal-Wallis test
result = stats.kruskal(*totals_by_day)

# Set the significance level (alpha) and interpret the results
alpha = 0.05

if result.pvalue < alpha:
    print("Reject the null hypothesis.")
    print("The total invoice amount varies based on the day of the week.")
else:
    print("Fail to reject the null hypothesis.")
    print("The total invoice amount is the same for all days of the week.")
# Out:
# Fail to reject the null hypothesis.
# The total invoice amount is the same for all days of the week.

# %%
# Hypothesis: There is a difference in the average invoice total depending on the item name.

# Null hypothesis (H0): There is no difference in the average invoice total depending on the item name.

# Alternative hypothesis (H1): There is a difference in the average invoice total depending on the item name.

# Group the data by item name and calculate the total invoice amount for each item
item_totals = reduced_data.groupby('Item Name')['Total'].sum()

# Convert the item totals into a list for each item
item_groups = [item_totals[item_name] for item_name in item_totals.index]

# Perform the Kruskal-Wallis test
result = stats.kruskal(*item_groups)

# Set the significance level (alpha) and interpret the results
alpha = 0.05

if result.pvalue < alpha:
    print("Reject the null hypothesis.")
    print("There is a difference in the average invoice total depending on the item name.")
else:
    print("Fail to reject the null hypothesis.")
    print("There is no difference in the average invoice total depending on the item name.")
# Out:
# Fail to reject the null hypothesis.
# There is no difference in the average invoice total depending on the item name.

# %%
# Hypothesis: There is a relationship between the item name and the customer name in terms of their occurrence in the dataset.

# Null hypothesis (H0): There is no relationship between the item name and the customer name.

# Alternative hypothesis (H1): There is a relationship between the item name and the customer name.

# Create a contingency table of item name and customer name
contingency_table = pd.crosstab(reduced_data['Item Name'], reduced_data['Customer Name'])

# Perform the chi-square test
chi2, p_value, dof, expected = stats.chi2_contingency(contingency_table)

# Set the significance level (alpha) and interpret the results
alpha = 0.05

if p_value < alpha:
    print("Reject the null hypothesis.")
    print("There is a relationship between the item name and the customer name.")
else:
    print("Fail to reject the null hypothesis.")
    print("There is no relationship between the item name and the customer name.")
# Out:
# Reject the null hypothesis.
# There is a relationship between the item name and the customer name.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Select the numerical columns for PCA
selected_columns = ['SubTotal', 'Total', 'Balance', 'Quantity', 'Item Total', 'Item Price']

# Create a subset DataFrame with the selected columns
subset_df = reduced_data[selected_columns]

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(subset_df)

# Apply PCA
pca = PCA(n_components=2)  # Specify the number of components to retain
pca_result = pca.fit_transform(scaled_data)

# Create a new DataFrame with PCA results
pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])

print(pca_df)
# Out:
#             PC1       PC2
# 0     -1.143647  0.500149
# 1     -0.803054  1.025351
# 2     -1.037782  0.590585
# 3     -1.175210  0.146944
# 4     -0.770085  1.270289
# ...         ...       ...
# 18355 -1.605765  0.264286
# 18356 -1.650817  0.114566
# 18357 -1.637495 -0.408055
# 18358 -1.650010 -0.174797
# 18359 -1.658950 -0.008184
#
# [18360 rows x 2 columns]

# %%
correlation_matrix = reduced_data.corr(method='pearson')
print(correlation_matrix)
# Out:
#              Invoice ID  Customer ID  SubTotal     Total   Balance  Quantity  \
# Invoice ID     1.000000     0.005230  0.069994  0.069994  0.079421  0.015342
# Customer ID    0.005230     1.000000 -0.056529 -0.056529 -0.046215  0.040984
# SubTotal       0.069994    -0.056529  1.000000  1.000000  0.991164  0.312179
# Total          0.069994    -0.056529  1.000000  1.000000  0.991164  0.312179
# Balance        0.079421    -0.046215  0.991164  0.991164  1.000000  0.307677
# Quantity       0.015342     0.040984  0.312179  0.312179  0.307677  1.000000
# Item Total     0.015393     0.023105  0.385858  0.385858  0.381329  0.730708
# Item Price     0.009709    -0.017548  0.020850  0.020850  0.024161 -0.224680
# Product ID    -0.004086     0.046870 -0.005764 -0.005764 -0.004838 -0.009394
#
#              Item Total  Item Price  Product ID
# Invoice ID     0.015393    0.009709   -0.004086
# Customer ID    0.023105   -0.017548    0.046870
# SubTotal       0.385858    0.020850   -0.005764
# Total          0.385858    0.020850   -0.005764
# Balance        0.381329    0.024161   -0.004838
# Quantity       0.730708   -0.224680   -0.009394
# Item Total     1.000000    0.032268    0.000082
# Item Price     0.032268    1.000000    0.028280
# Product ID     0.000082    0.028280    1.000000
# C:\Users\Antino\AppData\Local\Temp\ipykernel_17192\1016108417.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = reduced_data.corr(method='pearson')

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Select the features (X) and target variable (y)
features = reduced_data[['SubTotal', 'Total', 'Balance', 'Quantity', 'Item Total', 'Item Price']]  # Replace with your actual feature columns
target = reduced_data['Invoice ID']  # Replace with your actual target variable column

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Create and fit the CART regression model
cart_model = DecisionTreeRegressor(random_state=42)
cart_model.fit(X_train, y_train)

# Predict on the test set
y_pred = cart_model.predict(X_test)

# Evaluate the model using mean squared error
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 3745632924939.991
